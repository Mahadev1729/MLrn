# %% [markdown]
#  support Vector Regression Implementation

# %%
import seaborn as sns
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
# ind and dep features
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
X=df[['tip', 'sex', 'smoker', 'day', 'time', 'size']]
y=df['total_bill']

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.25,random_state=42);

# %%
X_train
# Out:
#       tip     sex smoker  day    time  size
# 115  3.50  Female     No  Sun  Dinner     2
# 181  5.65    Male    Yes  Sun  Dinner     2
# 225  2.50  Female    Yes  Fri   Lunch     2
# 68   2.01    Male     No  Sat  Dinner     2
# 104  4.08  Female     No  Sat  Dinner     2
# ..    ...     ...    ...  ...     ...   ...
# 106  4.06    Male    Yes  Sat  Dinner     2
# 14   3.02  Female     No  Sun  Dinner     2
# 92   1.00  Female    Yes  Fri  Dinner     2
# 179  3.55    Male    Yes  Sun  Dinner     2
# 102  2.50  Female    Yes  Sat  Dinner     3
#
# [183 rows x 6 columns]

# %%
X_test
# Out:
#       tip     sex smoker   day    time  size
# 24   3.18    Male     No   Sat  Dinner     2
# 6    2.00    Male     No   Sun  Dinner     2
# 153  2.00    Male     No   Sun  Dinner     4
# 211  5.16    Male    Yes   Sat  Dinner     4
# 198  2.00  Female    Yes  Thur   Lunch     2
# ..    ...     ...    ...   ...     ...   ...
# 172  5.15    Male    Yes   Sun  Dinner     2
# 242  1.75    Male     No   Sat  Dinner     2
# 152  2.74    Male     No   Sun  Dinner     3
# 231  3.00    Male    Yes   Sat  Dinner     3
# 155  5.14  Female     No   Sun  Dinner     5
#
# [61 rows x 6 columns]

# %%
y_train
# Out:
# 115    17.31
# 181    23.33
# 225    16.27
# 68     20.23
# 104    20.92
#        ...
# 106    20.49
# 14     14.83
# 92      5.75
# 179    34.63
# 102    44.30
# Name: total_bill, Length: 183, dtype: float64

# %%
y_test
# Out:
# 24     19.82
# 6       8.77
# 153    24.55
# 211    25.89
# 198    13.00
#        ...
# 172     7.25
# 242    17.82
# 152    17.26
# 231    15.69
# 155    29.85
# Name: total_bill, Length: 61, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1=LabelEncoder()
le2=LabelEncoder()
le3=LabelEncoder()

# %%
X_train['sex']=le1.fit_transform(X_train['sex'])
X_train['smoker']=le2.fit_transform(X_train['smoker'])
X_train['time']=le3.fit_transform(X_train['time'])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
X_train
# Out:
#       tip  sex  smoker  day  time  size
# 115  3.50    0       0  Sun     0     2
# 181  5.65    1       1  Sun     0     2
# 225  2.50    0       1  Fri     1     2
# 68   2.01    1       0  Sat     0     2
# 104  4.08    0       0  Sat     0     2
# ..    ...  ...     ...  ...   ...   ...
# 106  4.06    1       1  Sat     0     2
# 14   3.02    0       0  Sun     0     2
# 92   1.00    0       1  Fri     0     2
# 179  3.55    1       1  Sun     0     2
# 102  2.50    0       1  Sat     0     3
#
# [183 rows x 6 columns]

# %%
X_train.head()
# Out:
#       tip  sex  smoker  day  time  size
# 115  3.50    0       0  Sun     0     2
# 181  5.65    1       1  Sun     0     2
# 225  2.50    0       1  Fri     1     2
# 68   2.01    1       0  Sat     0     2
# 104  4.08    0       0  Sat     0     2

# %%
X_test['sex']=le1.transform(X_test['sex'])
X_test['smoker']=le2.transform(X_test['smoker'])
X_test['time']=le3.transform(X_test['time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 X_test['sex']=le1.transform(X_test['sex'])
#       2 X_test['smoker']=le2.transform(X_test['smoker'])
#       3 X_test['time']=le3.transform(X_test['time'])
#
# File d:\MLearn\myenv\Lib\site-packages\sklearn\preprocessing\_label.py:129, in LabelEncoder.transform(self, y)
#     127 check_is_fitted(self)
#     128 xp, _ = get_namespace(y)
# --> 129 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     130 # transform of empty array is empty array
#     131 if _num_samples(y) == 0:
#
# File d:\MLearn\myenv\Lib\site-packages\sklearn\utils\validation.py:1454, in column_or_1d(y, dtype, warn, device)
#    1416 """Ravel column or 1d numpy array, else raises an error.
#    1417
#    1418 Parameters
#    (...)   1451 array([1, 1])
#    1452 """
#    1453 xp, _ = get_namespace(y)
# -> 1454 y = check_array(
#    1455     y,
#    1456     ensure_2d=False,
#    1457     dtype=dtype,
#    1458     input_name="y",
#    1459     ensure_all_finite=False,
#    1460     ensure_min_samples=0,
#    1461 )
#    1463 shape = y.shape
#    1464 if len(shape) == 1:
#
# File d:\MLearn\myenv\Lib\site-packages\sklearn\utils\validation.py:1051, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     if xp.isdtype(array.dtype, ("real floating", "complex floating")):
#    1044         _assert_all_finite(
#    1045             array,
#    1046             allow_nan=False,
#    (...)   1049             input_name=input_name,
#    1050         )
# -> 1051     array = xp.astype(array, dtype, copy=False)
#    1052 else:
#    1053     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#
# File d:\MLearn\myenv\Lib\site-packages\sklearn\externals\array_api_compat\numpy\_aliases.py:127, in astype(x, dtype, copy, device)
#     119 def astype(
#     120     x: ndarray,
#     121     dtype: Dtype,
#    (...)    125     device: Optional[Device] = None,
#     126 ) -> ndarray:
# --> 127     return x.astype(dtype=dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Male'

# %%
#one hot encoding

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct=ColumnTransformer(transformers=[('onehot',OneHotEncoder(drop='first'),3),remainder='drop'])
