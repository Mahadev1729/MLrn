# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Algerian_Update.csv')

# %%
df_copy=df

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  243 non-null    int64
#  1   Unnamed: 0    243 non-null    int64
#  2   day           243 non-null    float64
#  3   month         243 non-null    float64
#  4   year          243 non-null    float64
#  5   Temperature   243 non-null    float64
#  6    RH           243 non-null    float64
#  7    Ws           243 non-null    float64
#  8   Rain          243 non-null    float64
#  9   FFMC          243 non-null    float64
#  10  DMC           243 non-null    float64
#  11  DC            243 non-null    float64
#  12  ISI           243 non-null    float64
#  13  BUI           243 non-null    float64
#  14  FWI           243 non-null    float64
#  15  Classes       243 non-null    object
# dtypes: float64(13), int64(2), object(1)
# memory usage: 30.5+ KB

# %%
df_copy.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'day', 'month', 'year', 'Temperature',
#        ' RH', ' Ws', 'Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI',
#        'Classes  '],
#       dtype='object')

# %%
df_copy.columns=df_copy.columns.str.strip()

# %%
df_copy.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'day', 'month', 'year', 'Temperature',
#        'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI',
#        'Classes'],
#       dtype='object')

# %%
df_copy.to_csv('Try.csv')

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df['Classes'] = df['Classes'].astype(str).str.strip()
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy
# Out:
#      Unnamed: 0.1  Unnamed: 0   day  month    year  Temperature    RH    Ws  \
# 0               0           0   1.0    6.0  2012.0         29.0  57.0  18.0
# 1               1           1   2.0    6.0  2012.0         29.0  61.0  13.0
# 2               2           2   3.0    6.0  2012.0         26.0  82.0  22.0
# 3               3           3   4.0    6.0  2012.0         25.0  89.0  13.0
# 4               4           4   5.0    6.0  2012.0         27.0  77.0  16.0
# ..            ...         ...   ...    ...     ...          ...   ...   ...
# 238           238         242  26.0    9.0  2012.0         30.0  65.0  14.0
# 239           239         243  27.0    9.0  2012.0         28.0  87.0  15.0
# 240           240         244  28.0    9.0  2012.0         27.0  87.0  29.0
# 241           241         245  29.0    9.0  2012.0         24.0  54.0  18.0
# 242           242         246  30.0    9.0  2012.0         24.0  64.0  15.0
#
#      Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes
# ...

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
sns.pairplot(df_copy)

# %%
df_copy
# Out:
#      Unnamed: 0.1  Unnamed: 0   day  month    year  Temperature    RH    Ws  \
# 0               0           0   1.0    6.0  2012.0         29.0  57.0  18.0
# 1               1           1   2.0    6.0  2012.0         29.0  61.0  13.0
# 2               2           2   3.0    6.0  2012.0         26.0  82.0  22.0
# 3               3           3   4.0    6.0  2012.0         25.0  89.0  13.0
# 4               4           4   5.0    6.0  2012.0         27.0  77.0  16.0
# ..            ...         ...   ...    ...     ...          ...   ...   ...
# 238           238         242  26.0    9.0  2012.0         30.0  65.0  14.0
# 239           239         243  27.0    9.0  2012.0         28.0  87.0  15.0
# 240           240         244  28.0    9.0  2012.0         27.0  87.0  29.0
# 241           241         245  29.0    9.0  2012.0         24.0  54.0  18.0
# 242           242         246  30.0    9.0  2012.0         24.0  64.0  15.0
#
#      Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes
# ...

# %%
df_copy.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'day', 'month', 'year', 'Temperature',
#        'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI',
#        'Classes'],
#       dtype='object')

# %%
del df_copy['Unnamed: 0.1']
del df_copy['Unnamed: 0']
del df_copy['day']
del df_copy['month']
del df_copy['year']

# %%
df_copy
# Out:
#      Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes
# 0           29.0  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1           29.0  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2           26.0  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3           25.0  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4           27.0  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...   ...   ...   ...   ...   ...   ...  ...   ...  ...      ...
# 238         30.0  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239         28.0  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240         27.0  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241         24.0  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242         24.0  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
# [243 rows x 11 columns]

# %%
sns.pairplot(df_copy)

# %%
## density plot
plt.style.use('seaborn')
df_copy.hist(bins=10,figsize=(20,15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\MLearn\myenv\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File d:\MLearn\myenv\Lib\site-packages\matplotlib\__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File d:\MLearn\myenv\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File d:\MLearn\myenv\Lib\site-packages\matplotlib\__init__.py:880, in _open_file_or_url(fname)
#     879 fname = os.path.expanduser(fname)
# --> 880 with open(fname, encoding='utf-8') as f:
#     881     yield f
#
# ...

# %%
plt.style.use('seaborn-v0_8')


df_copy.hist(bins=100, figsize=(20, 15))
plt.show()

# %%
## pie chart
dfClasses_perc=df_copy['Classes'].value_counts(normalize=True)*100
dfClasses_perc
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
## ploting pie chart

classLabels=['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pie(dfClasses_perc,labels=classLabels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2136234ad80>,
# ...
#  [Text(-0.2189564657232264, 1.0779879712306597, 'Fire'),
#   Text(0.21895655996393085, -1.0779879520888727, 'Not Fire')],
#  [Text(-0.11943079948539621, 0.5879934388530871, '56.4%'),
#   Text(0.11943085088941681, -0.5879934284121123, '43.6%')])
