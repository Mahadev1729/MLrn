# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('ModelTraining.csv')
df
# Out:
#      Unnamed: 0   day  month    year  Temperature    RH    Ws  Rain   FFMC  \
# 0             0   1.0    6.0  2012.0         29.0  57.0  18.0    0.0  65.7
# 1             1   2.0    6.0  2012.0         29.0  61.0  13.0    1.3  64.4
# 2             2   3.0    6.0  2012.0         26.0  82.0  22.0   13.1  47.1
# 3             3   4.0    6.0  2012.0         25.0  89.0  13.0    2.5  28.6
# 4             4   5.0    6.0  2012.0         27.0  77.0  16.0    0.0  64.8
# ..          ...   ...    ...     ...          ...   ...   ...    ...   ...
# 238         238  26.0    9.0  2012.0         30.0  65.0  14.0    0.0  85.4
# 239         239  27.0    9.0  2012.0         28.0  87.0  15.0    4.4  41.1
# 240         240  28.0    9.0  2012.0         27.0  87.0  29.0    0.5  45.9
# 241         241  29.0    9.0  2012.0         24.0  54.0  18.0    0.1  79.7
# 242         242  30.0    9.0  2012.0         24.0  64.0  15.0    0.2  67.3
#
#       DMC    DC  ISI   BUI  FWI     Classes
# 0     3.4   7.6  1.3   3.4  0.5   not fire
# 1     4.1   7.6  1.0   3.9  0.4   not fire
# 2     2.5   7.1  0.3   2.7  0.1   not fire
# 3     1.3   6.9  0.0   1.7  0.0   not fire
# 4     3.0  14.2  1.2   3.9  0.5   not fire
# ..    ...   ...  ...   ...  ...           ...
# 238  16.0  44.5  4.5  16.9  6.5       fire
# 239   6.5   8.0  0.1   6.2  0.0   not fire
# 240   3.5   7.9  0.4   3.4  0.2   not fire
# 241   4.3  15.2  1.7   5.1  0.7   not fire
# 242   3.8  16.5  1.2   4.8  0.5  not fire
#
# [243 rows x 15 columns]

# %%
del df['Unnamed: 0']

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
df.drop('day',axis=1)
# Out:
#      month    year  Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI  \
# 0      6.0  2012.0         29.0  57.0  18.0   0.0  65.7   3.4   7.6  1.3
# 1      6.0  2012.0         29.0  61.0  13.0   1.3  64.4   4.1   7.6  1.0
# 2      6.0  2012.0         26.0  82.0  22.0  13.1  47.1   2.5   7.1  0.3
# 3      6.0  2012.0         25.0  89.0  13.0   2.5  28.6   1.3   6.9  0.0
# 4      6.0  2012.0         27.0  77.0  16.0   0.0  64.8   3.0  14.2  1.2
# ..     ...     ...          ...   ...   ...   ...   ...   ...   ...  ...
# 238    9.0  2012.0         30.0  65.0  14.0   0.0  85.4  16.0  44.5  4.5
# 239    9.0  2012.0         28.0  87.0  15.0   4.4  41.1   6.5   8.0  0.1
# 240    9.0  2012.0         27.0  87.0  29.0   0.5  45.9   3.5   7.9  0.4
# 241    9.0  2012.0         24.0  54.0  18.0   0.1  79.7   4.3  15.2  1.7
# 242    9.0  2012.0         24.0  64.0  15.0   0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI       Classes
# 0     3.4  0.5   not fire
# 1     3.9  0.4   not fire
# 2     2.7  0.1   not fire
# 3     1.7  0.0   not fire
# 4     3.9  0.5   not fire
# ..    ...  ...           ...
# 238  16.9  6.5       fire
# 239   6.2  0.0   not fire
# 240   3.4  0.2   not fire
# 241   5.1  0.7   not fire
# 242   4.8  0.5  not fire
#
# [243 rows x 13 columns]

# %%
df.drop('month',axis=1)
# Out:
#       day    year  Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0     1.0  2012.0         29.0  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4
# 1     2.0  2012.0         29.0  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9
# 2     3.0  2012.0         26.0  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7
# 3     4.0  2012.0         25.0  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7
# 4     5.0  2012.0         27.0  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9
# ..    ...     ...          ...   ...   ...   ...   ...   ...   ...  ...   ...
# 238  26.0  2012.0         30.0  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9
# 239  27.0  2012.0         28.0  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2
# 240  28.0  2012.0         27.0  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4
# 241  29.0  2012.0         24.0  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1
# 242  30.0  2012.0         24.0  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes
# 0    0.5   not fire
# 1    0.4   not fire
# 2    0.1   not fire
# 3    0.0   not fire
# 4    0.5   not fire
# ..   ...           ...
# 238  6.5       fire
# 239  0.0   not fire
# 240  0.2   not fire
# 241  0.7   not fire
# 242  0.5  not fire
#
# [243 rows x 13 columns]

# %%
df['Classes']=np.where(df['Classes'].str.contains("not fire"),0,1)

# %%
df
# Out:
#       day  month    year  Temperature    RH    Ws  Rain  FFMC   DMC    DC  \
# 0     1.0    6.0  2012.0         29.0  57.0  18.0   0.0  65.7   3.4   7.6
# 1     2.0    6.0  2012.0         29.0  61.0  13.0   1.3  64.4   4.1   7.6
# 2     3.0    6.0  2012.0         26.0  82.0  22.0  13.1  47.1   2.5   7.1
# 3     4.0    6.0  2012.0         25.0  89.0  13.0   2.5  28.6   1.3   6.9
# 4     5.0    6.0  2012.0         27.0  77.0  16.0   0.0  64.8   3.0  14.2
# ..    ...    ...     ...          ...   ...   ...   ...   ...   ...   ...
# 238  26.0    9.0  2012.0         30.0  65.0  14.0   0.0  85.4  16.0  44.5
# 239  27.0    9.0  2012.0         28.0  87.0  15.0   4.4  41.1   6.5   8.0
# 240  28.0    9.0  2012.0         27.0  87.0  29.0   0.5  45.9   3.5   7.9
# 241  29.0    9.0  2012.0         24.0  54.0  18.0   0.1  79.7   4.3  15.2
# 242  30.0    9.0  2012.0         24.0  64.0  15.0   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI  Classes
# 0    1.3   3.4  0.5        0
# 1    1.0   3.9  0.4        0
# 2    0.3   2.7  0.1        0
# 3    0.0   1.7  0.0        0
# 4    1.2   3.9  0.5        0
# ..   ...   ...  ...      ...
# 238  4.5  16.9  6.5        1
# 239  0.1   6.2  0.0        0
# 240  0.4   3.4  0.2        0
# 241  1.7   5.1  0.7        0
# 242  1.2   4.8  0.5        0
#
# [243 rows x 14 columns]

# %%
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes'],
#       dtype='object')

# %%
X=df.drop('FWI',axis=1)
y=df['FWI']

# %%
X.head,y.head
# Out:
# (<bound method NDFrame.head of      Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes
#  0           29.0  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4        0
#  1           29.0  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9        0
#  2           26.0  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7        0
#  3           25.0  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7        0
#  4           27.0  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9        0
#  ..           ...   ...   ...   ...   ...   ...   ...  ...   ...      ...
#  238         30.0  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9        1
#  239         28.0  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2        0
#  240         27.0  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4        0
#  241         24.0  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1        0
#  242         24.0  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8        0
#
#  [243 rows x 10 columns]>,
#  <bound method NDFrame.head of 0      0.5
#  1      0.4
#  2      0.1
#  3      0.0
#  4      0.5
#        ...
#  238    6.5
#  239    0.0
#  240    0.2
#  241    0.7
#  242    0.5
#  Name: FWI, Length: 243, dtype: float64>)

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (182, 10)

# %%
X_test.shape
# Out:
# (61, 10)

# %%
y_test.shape
# Out:
# (61,)

# %%
y_train.shape
# Out:
# (182,)
