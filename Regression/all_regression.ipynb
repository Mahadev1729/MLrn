# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Algerian_forest_fires_dataset.csv')
df
# Out:
#       day  month    year  Temperature    RH    Ws  Rain   FFMC   DMC    DC  \
# 0     1.0    6.0  2012.0         29.0  57.0  18.0    0.0  65.7   3.4   7.6
# 1     2.0    6.0  2012.0         29.0  61.0  13.0    1.3  64.4   4.1   7.6
# 2     3.0    6.0  2012.0         26.0  82.0  22.0   13.1  47.1   2.5   7.1
# 3     4.0    6.0  2012.0         25.0  89.0  13.0    2.5  28.6   1.3   6.9
# 4     5.0    6.0  2012.0         27.0  77.0  16.0    0.0  64.8   3.0  14.2
# ..    ...    ...     ...          ...   ...   ...    ...   ...   ...   ...
# 242  26.0    9.0  2012.0         30.0  65.0  14.0    0.0  85.4  16.0  44.5
# 243  27.0    9.0  2012.0         28.0  87.0  15.0    4.4  41.1   6.5     8
# 244  28.0    9.0  2012.0         27.0  87.0  29.0    0.5  45.9   3.5   7.9
# 245  29.0    9.0  2012.0         24.0  54.0  18.0    0.1  79.7   4.3  15.2
# 246  30.0    9.0  2012.0         24.0  64.0  15.0    0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI     Classes
# 0    1.3   3.4  0.5   not fire
# ...

# %%
df.isnull().sum()
# Out:
# day            3
# month          3
# year           3
# Temperature    3
#  RH            3
#  Ws            3
# Rain           3
# FFMC           3
# DMC            3
# DC             3
# ISI            3
# BUI            3
# FWI            3
# Classes        4
# dtype: int64

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    float64
#  1   month        244 non-null    float64
#  2   year         244 non-null    float64
#  3   Temperature  244 non-null    float64
#  4    RH          244 non-null    float64
#  5    Ws          244 non-null    float64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
# dtypes: float64(11), object(3)
# memory usage: 27.1+ KB

# %%
df.iloc[[126]]
# Out:
#      day  month    year  Temperature    RH    Ws  Rain   FFMC  DMC   DC  ISI  \
# 126  2.0    6.0  2012.0         30.0  73.0  13.0    4.0  55.7  2.7  7.8  0.6
#
#      BUI  FWI    Classes
# 126  2.9  0.2  not fire

# %%
df=df.dropna(axis=0, how='any', inplace=False)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# dtype: int64

# %%
df.tail()
# Out:
#       day  month    year  Temperature    RH    Ws  Rain   FFMC   DMC    DC  \
# 242  26.0    9.0  2012.0         30.0  65.0  14.0    0.0  85.4  16.0  44.5
# 243  27.0    9.0  2012.0         28.0  87.0  15.0    4.4  41.1   6.5     8
# 244  28.0    9.0  2012.0         27.0  87.0  29.0    0.5  45.9   3.5   7.9
# 245  29.0    9.0  2012.0         24.0  54.0  18.0    0.1  79.7   4.3  15.2
# 246  30.0    9.0  2012.0         24.0  64.0  15.0    0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI     Classes
# 242  4.5  16.9  6.5       fire
# 243  0.1   6.2    0   not fire
# 244  0.4   3.4  0.2   not fire
# 245  1.7   5.1  0.7   not fire
# 246  1.2   4.8  0.5  not fire

# %%
df.iloc[[122]]
# Out:
#      day  month    year  Temperature    RH    Ws  Rain   FFMC  DMC   DC  ISI  \
# 125  1.0    6.0  2012.0         32.0  71.0  12.0    0.7  57.1  2.5  8.2  0.6
#
#      BUI  FWI    Classes
# 125  2.8  0.2  not fire

# %%
df.to_csv('Algerian_dataset_Update.csv')

# %%
df_update=pd.read_csv('Algerian_dataset_Update.csv',header=0)
df_update
# Out:
#      Unnamed: 0   day  month    year  Temperature    RH    Ws  Rain   FFMC  \
# 0             0   1.0    6.0  2012.0         29.0  57.0  18.0    0.0  65.7
# 1             1   2.0    6.0  2012.0         29.0  61.0  13.0    1.3  64.4
# 2             2   3.0    6.0  2012.0         26.0  82.0  22.0   13.1  47.1
# 3             3   4.0    6.0  2012.0         25.0  89.0  13.0    2.5  28.6
# 4             4   5.0    6.0  2012.0         27.0  77.0  16.0    0.0  64.8
# ..          ...   ...    ...     ...          ...   ...   ...    ...   ...
# 238         242  26.0    9.0  2012.0         30.0  65.0  14.0    0.0  85.4
# 239         243  27.0    9.0  2012.0         28.0  87.0  15.0    4.4  41.1
# 240         244  28.0    9.0  2012.0         27.0  87.0  29.0    0.5  45.9
# 241         245  29.0    9.0  2012.0         24.0  54.0  18.0    0.1  79.7
# 242         246  30.0    9.0  2012.0         24.0  64.0  15.0    0.2  67.3
#
#       DMC    DC  ISI   BUI  FWI     Classes
# ...

# %%
del df_update['Unnamed: 0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\MLearn\myenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 del df_update['Unnamed: 0']
#       2 df_update
#
# ...

# %%
df_update
# Out:
#       day  month    year  Temperature    RH    Ws  Rain   FFMC   DMC    DC  \
# 0     1.0    6.0  2012.0         29.0  57.0  18.0    0.0  65.7   3.4   7.6
# 1     2.0    6.0  2012.0         29.0  61.0  13.0    1.3  64.4   4.1   7.6
# 2     3.0    6.0  2012.0         26.0  82.0  22.0   13.1  47.1   2.5   7.1
# 3     4.0    6.0  2012.0         25.0  89.0  13.0    2.5  28.6   1.3   6.9
# 4     5.0    6.0  2012.0         27.0  77.0  16.0    0.0  64.8   3.0  14.2
# ..    ...    ...     ...          ...   ...   ...    ...   ...   ...   ...
# 238  26.0    9.0  2012.0         30.0  65.0  14.0    0.0  85.4  16.0  44.5
# 239  27.0    9.0  2012.0         28.0  87.0  15.0    4.4  41.1   6.5   8.0
# 240  28.0    9.0  2012.0         27.0  87.0  29.0    0.5  45.9   3.5   7.9
# 241  29.0    9.0  2012.0         24.0  54.0  18.0    0.1  79.7   4.3  15.2
# 242  30.0    9.0  2012.0         24.0  64.0  15.0    0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI     Classes
# 0    1.3   3.4  0.5   not fire
# ...

# %%
df_update.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
## fix spacess in column name

df_update.columns=df_update.columns.str.strip()

# %%
df_update.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
df_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    float64
#  1   month        243 non-null    float64
#  2   year         243 non-null    float64
#  3   Temperature  243 non-null    float64
#  4   RH           243 non-null    float64
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(13), object(1)
# memory usage: 26.7+ KB

# %% [markdown]
# ## change the required column as data into type

# %%
df_update.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
df_update[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']]=df_update[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df_update.info()
df_update.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 26.7+ KB
# (243, 14)

# %%
objects=[feat for feat in df_update.columns if df_update[feat].dtypes == 'O']

# %%
for i in objects:
    if i!='Classes':
        df_update[i]=df_update[i].astype(float)
df_update
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes
# ...

# %%
df_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 26.7+ KB
