# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sales=pd.read_csv('sales_dataset.csv')
df_sales
# Out:
#       Product       Date  Units Sold  Price per Unit
# 0      Laptop  1 01 2024          15             800
# 1       Phone  2 01 2024          30             600
# 2  Headphones  3 01 2024          45             100
# 3      Tablet  4 01 2024          10             400
# 4      Laptop  1 02 2024          20             800
# 5       Phone  2 02 2024          35             600
# 6  Headphones  3 02 2024          50             100
# 7      Tablet  4 02 2024          15             400

# %%
df_sales.isnull()
# Out:
#    Product   Date  Units Sold  Price per Unit
# 0    False  False       False           False
# 1    False  False       False           False
# 2    False  False       False           False
# 3    False  False       False           False
# 4    False  False       False           False
# 5    False  False       False           False
# 6    False  False       False           False
# 7    False  False       False           False

# %%
df_sales.columns
# Out:
# Index(['Product', 'Date', 'Units Sold', 'Price per Unit'], dtype='object')

# %%
df_sales.columns
# Out:
# Index(['Product', 'Date', 'Units Sold', 'Price per Unit'], dtype='object')

# %%
plt.scatter(df_sales['Date'],df_sales['Price per Unit'])
plt.xlabel('Date')
plt.ylabel('Price per Unit')
plt.show()

# %%
plt.scatter(df_sales['Date'],df_sales['Units Sold'])

# %%
x=df_sales['Date']

# %%
y=df_sales['Price per Unit']

# %%
del df_sales['Product']

# %%
df_sales
# Out:
#         Date  Units Sold  Price per Unit
# 0  1 01 2024          15             800
# 1  2 01 2024          30             600
# 2  3 01 2024          45             100
# 3  4 01 2024          10             400
# 4  1 02 2024          20             800
# 5  2 02 2024          35             600
# 6  3 02 2024          50             100
# 7  4 02 2024          15             400

# %%
sns.pairplot(df_sales)

# %%
X=df_sales[['Price per Unit']]
X
y=df_sales['Units Sold']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#         Date  Price per Unit
# 0  1 01 2024             800
# 7  4 02 2024             400
# 2  3 01 2024             100
# 4  1 02 2024             800
# 3  4 01 2024             400
# 6  3 02 2024             100

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
# print(scaler)
# print(type(scaler)) 
scaler.fit_transform(X_train)
# Out:
# StandardScaler()
# <class 'sklearn.preprocessing._data.StandardScaler'>
# array([[ 1.27872403],
#        [-0.11624764],
#        [-1.16247639],
#        [ 1.27872403],
#        [-0.11624764],
#        [-1.16247639]])

# %%
from sklearn.linear_model import LinearRegression

regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(X_test)

# %%
df_sales
# Out:
#         Date  Units Sold  Price per Unit
# 0  1 01 2024          15             800
# 1  2 01 2024          30             600
# 2  3 01 2024          45             100
# 3  4 01 2024          10             400
# 4  1 02 2024          20             800
# 5  2 02 2024          35             600
# 6  3 02 2024          50             100
# 7  4 02 2024          15             400

# %%
del df_sales['Date']

# %%
sns.heatmap(df_sales.corr())
# Out:
# <Axes: >
